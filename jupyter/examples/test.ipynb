# %% [markdown]
# # Title
# ## sub-title
# ### sub-sub-title
# #### sub-sub-sub-title
# ##### sub-sub-sub-sub-title
#
# - item 1
# - item 2
# - item 3
# - item 4
#
# 1. item 1
# 2. item 2
# 3. item 3
# 4. item 4
#    - sub-item 1
#    - sub-item 2
# 5. item 5
#
# | Firstname | Lastname | fullname |
# | --------- | -------- | -------- |
# | John      | Doe      | John Doe |
# | Antonio   | Pisanello| Antonio Pisanello |
#
# I want to `higlight` this text.
#
# **bold text**
#
# *italic text*
#
# Hello from the Applied data analysis class

# %%
a = 10
b = 23

c = a + b
print(c)
# Out:
# 33

# %%
a = 10
b = 23

c = a + b
c
# Out:
# 33
