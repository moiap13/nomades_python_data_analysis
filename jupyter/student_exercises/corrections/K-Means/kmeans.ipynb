# %% [markdown]
# # KMeans

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

from kmeans import KMeans

# %%
plt.style.use('default')

# %%
K:int = 3
N:int = 100
np.random.seed(1000)

# %%
random_points = np.random.randint(0, 100, (100, 2))

# %%
random_points
# Out:
# array([[51, 87],
#        [71, 64],
#        [94, 92],
#        [ 1, 61],
#        [ 0, 89],
#        [45, 40],
#        [92, 91],
#        [36, 60],
#        [42, 58],
#        [41, 20],
#        [30, 88],
#        [30, 28],
#        [30, 77],
#        [82, 28],
#        [85, 93],
#        [10, 30],
#        [14, 61],
#        [69, 76],
#        [11, 52],
#        [75, 32],
#        [52, 50],
#        [21, 26],
#        [ 7, 16],
#        [87, 92],
#        [43, 59],
#        [ 0, 31],
#        [30, 18],
#        [ 1, 11],
#        [46, 27],
#        [47, 87],
#        [79, 17],
#        [69, 54],
#        [29, 11],
#        [12,  5],
#        [55, 88],
#        [72, 18],
#        [ 2, 77],
#        [59, 41],
#        [ 6, 10],
#        [35, 51],
#        [53, 47],
#        [56, 20],
#        [65, 96],
#        [25, 81],
#        [72, 48],
#        [ 2, 75],
#        [73, 13],
#        [63, 19],
#        [78, 58],
#        [ 9,  6],
#        [82, 85],
#        [56, 27],
#        [21, 54],
#        [86, 76],
#        [91, 27],
#        [55, 86],
#        [36, 91],
#        [93, 72],
#        [97, 67],
#        [77, 95],
#        [71, 18],
#        [ 0, 93],
#        [46, 84],
#        [81, 86],
#        [61, 30],
#        [45,  1],
#        [20, 36],
#        [85, 48],
#        [34, 89],
#        [30, 63],
#        [23, 96],
#        [76, 11],
#        [ 8, 32],
#        [53, 19],
#        [32, 20],
#        [35, 99],
#        [43, 99],
#        [93,  4],
#        [60,  2],
#        [36, 18],
#        [52, 81],
#        [12, 47],
#        [18,  3],
#        [89,  0],
#        [44, 44],
#        [44, 91],
#        [53, 18],
#        [17, 47],
#        [22, 41],
#        [86,  1],
#        [81, 78],
#        [77, 32],
#        [88, 84],
#        [34, 98],
#        [33, 72],
#        [28, 98],
#        [48, 97],
#        [81, 97],
#        [67, 13],
#        [28, 77]])

# %%
plt.style.use('default')
plt.scatter(random_points[:, 0], random_points[:, 1])

# %%
kmeans = KMeans(k=K, max_iters=100)
kmeans.fit(random_points)
# Out:
# [0 0]
# array([], dtype=float64)

# %%
# print(kmeans.centroids)
# print(kmeans.labels)

plt.style.use('default')
plt.scatter(random_points[:, 0], random_points[:, 1], c=kmeans.labels, cmap='viridis')
plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], c=range(len(kmeans.centroids)), marker='x', s=200, label='Centroids')
plt.show()
# Out:
# [0 0]
# /var/folders/64/8wr_1w5d38s7ynhph9nnfbhm0000gn/T/ipykernel_12245/460749967.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(random_points[:, 0], random_points[:, 1], c=kmeans.labels, cmap='viridis')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       7 plt.style.use('default')
#       8 plt.scatter(random_points[:, 0], random_points[:, 1], c=kmeans.labels, cmap='viridis')
# ----> 9 plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], c=range(len(kmeans.centroids)), marker='x', s=200, label='Centroids')
#      10 plt.show()
#
# TypeError: 'NoneType' object is not subscriptable
