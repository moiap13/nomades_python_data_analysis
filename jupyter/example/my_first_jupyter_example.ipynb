# %% [markdown]
# # My first jupyter
#
# We'lll write "hello world" string to the screen

# %%
print("hello World !")
# Out:
# hello World !

# %%
c = a+b
print(c)
# Out:
# 112

# %%
a = 100

# %%
b = 12

# %%
def add(a:int, b: int) -> int: return a*b

# %%
print(add(10, 12))
# Out:
# 120
